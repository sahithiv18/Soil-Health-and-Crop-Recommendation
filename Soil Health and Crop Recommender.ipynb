# %%
from tensorflow.keras import datasets 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
plt.style.use('seaborn')
import statsmodels.api as sm
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
crop_name = {
    1 : ['Rice' , 'Mango', 'Papaya' ],
    2 : ['Cotton', 'Jute', 'Watermelon', 'Muskmelon', 'Banana', 'Orange'],
    3 : ['Jute', 'Watermelon', 'Muskmelon'],
    4 : ['Rice', 'Jute', 'Watermelon', 'Muskmelon', 'Cotton', 'Jute',  'Banana', 'Orange' ],
    5 : ['Pomegranate'],
    6 : ['Apple', 'Grape', 'Pomegranate'],
    7 : ['Lentil'],
    8 : ['Lentil' , 'Jute', 'Watermelon', 'Muskmelon']
}

# %% [markdown]
# #Feature Selection and PreProcessing

# %%
df = pd.read_csv("final_data.csv")

# %%
X = df[['pH', 'EC', 'OC', 'N', 'P', 'K', 'S', 'Ca', 'Mg', 'Zn', 'Cu',
       'Fe', 'Mn','Tex']]
y = df['label']

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(len(df.columns)*2,4))
for index, col in enumerate(df.columns):
    ax = axes[index]
    sns.boxplot(y=df.loc[:,col], x=df.loc[:,'label'], ax=ax)
    ax.set_ylabel(ax.get_ylabel(), fontsize='x-large')
    ax.set_xlabel("")
plt.tight_layout(pad=0.5)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.District= le.fit_transform(df.District.values)

# %%
df.Tex= le.fit_transform(df.Tex.values)

# %%
X
# Out:
#             pH        EC         OC           N          P           K  \
# 0     7.050000  0.160000   5.560000  175.620000  38.260000  324.800000
# 1     6.880000  0.089000   4.240000  125.440000  26.300000  103.000000
# 2     5.600000  0.081000   2.780000  150.530000  25.700000   53.800000
# 3     7.300000  0.164000  10.540000  188.160000  24.700000  190.400000
# 4     7.220000  0.167000  11.410000  163.070000  40.000000  210.600000
# ...        ...       ...        ...         ...        ...         ...
# 2732  6.531352  0.659126  17.283696  507.723181  28.210970   99.076266
# 2733  6.570766  0.672140  17.198919  507.854437  28.107230   99.429503
# 2734  6.989972  0.810557  16.297230  509.250472  27.003848  103.186541
# 2735  6.737222  0.727102  16.840881  508.408768  27.669104  100.921331
# 2736  6.215602  0.554868  17.962857  506.671674  29.042048   96.246431
#
#                S    Ca          Mg         Zn         Cu         Fe  \
# 0       5.210000  1884  288.000000   1.820000   0.200000   2.830000
# 1      10.420000  1484  336.000000   1.620000   0.450000   6.270000
# 2       7.810000  1644  504.000000   2.840000   0.440000  21.080000
# 3      10.420000  1364  840.000000   7.740000   0.630000  16.420000
# 4      10.420000  2004  168.000000  11.890000   0.610000   7.380000
# ...          ...   ...         ...        ...        ...        ...
# 2732  464.099932    57    1.407825   0.908700  26.714008  20.307160
# 2733  462.612618    60    1.410428   0.898288  25.791129  19.426670
# 2734  446.793514    93    1.438111   0.787555  15.975375  10.061760
# 2735  456.331240    73    1.421420   0.854319  21.893534  15.708094
# 2736  476.015029    32    1.386974   0.992105  34.107325  27.360897
#
#              Mn  Tex
# 0      2.800000    2
# 1      5.600000    2
# 2     24.110000    5
# 3     11.400000    2
# 4      2.910000    2
# ...         ...  ...
# 2732   8.306451   14
# 2733   8.329504   14
# 2734   8.574701   16
# 2735   8.426866   15
# 2736   8.121767   12
#
# [2737 rows x 14 columns]

# %%
y
# Out:
# 0       6
# 1       7
# 2       7
# 3       6
# 4       6
#        ..
# 2732    8
# 2733    8
# 2734    8
# 2735    8
# 2736    8
# Name: label, Length: 2737, dtype: int64

# %%
X = (X - X.mean())/X.std()
X
# Out:
#             pH        EC        OC         N         P         K         S  \
# 0     1.048506 -1.037491 -1.677114 -1.226424  0.557077  1.249438 -1.023138
# 1     0.650186 -1.200279 -1.911359 -1.594217 -0.124451 -0.593699 -1.014431
# 2    -2.348933 -1.218622 -2.170448 -1.410321 -0.158642 -1.002546 -1.018793
# 3     1.634272 -1.028320 -0.793373 -1.134513 -0.215626  0.132587 -1.014431
# 4     1.446827 -1.021441 -0.638984 -1.318409  0.656229  0.300447 -1.014431
# ...        ...       ...       ...       ...       ...       ...       ...
# 2732 -0.166718  0.106901  0.403351  1.207717 -0.015557 -0.626305 -0.256227
# 2733 -0.074369  0.136739  0.388306  1.208679 -0.021468 -0.623369 -0.258713
# 2734  0.907857  0.454101  0.228294  1.218911 -0.084343 -0.592149 -0.285150
# 2735  0.315649  0.262756  0.324770  1.212742 -0.046434 -0.610972 -0.269211
# 2736 -0.906540 -0.132139  0.523873  1.200010  0.031801 -0.649820 -0.236315
#
#             Ca        Mg        Zn        Cu        Fe        Mn       Tex
# 0     1.526581  0.178608 -0.192447 -0.946238 -1.027180 -0.943989 -2.426073
# 1     1.071609  0.288384 -0.255630 -0.931182 -0.754868 -0.599579 -2.426073
# 2     1.253598  0.672599  0.129790 -0.931784  0.417502  1.677216 -1.721297
# 3     0.935117  1.441030  1.677788 -0.920342  0.048613  0.113841 -2.426073
# 4     1.663073 -0.095832  2.988847 -0.921546 -0.666999 -0.930458 -2.426073
# ...        ...       ...       ...       ...       ...       ...       ...
# 2732 -0.551505 -0.476827 -0.480343  0.650537  0.356323 -0.266676  0.393030
# 2733 -0.548092 -0.476821 -0.483632  0.594957  0.286623 -0.263840  0.393030
# 2734 -0.510557 -0.476758 -0.518615  0.003815 -0.454709 -0.233680  0.862880
# 2735 -0.533306 -0.476796 -0.497523  0.360229 -0.007742 -0.251865  0.627955
# 2736 -0.579940 -0.476875 -0.453993  1.095790  0.914702 -0.289393 -0.076821
#
# [2737 rows x 14 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (2189, 14) (548, 14) (2189,) (548,)

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifer = DecisionTreeClassifier(criterion='entropy', random_state=0)
# providing the training dataset
classifer.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifer.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# accuracy
graph = accuracy_score(y_pred,y_test)
graph
# Out:
# 0.9963503649635036

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
clf = DecisionTreeClassifier()

# output size of decision tree
plt.figure(figsize=(40,20))

# providing the training dataset
clf = clf.fit(X_train, y_train)
plot_tree(clf, filled=True)
plt.title("Decision tree training for training dataset")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
clf = DecisionTreeClassifier()

# output size of decision tree
plt.figure(figsize=(40,20))

# providing the training dataset
clf = clf.fit(X_test, y_test)
plot_tree(clf, filled=True)
plt.title("Decision tree training for testing dataset")
plt.show()

# %%
from sklearn import tree

# text based tree
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_3 <= -0.46
# |   |--- feature_5 <= -0.46
# |   |   |--- class: 7
# |   |--- feature_5 >  -0.46
# |   |   |--- class: 6
# |--- feature_3 >  -0.46
# |   |--- feature_4 <= -0.22
# |   |   |--- feature_3 <= -0.34
# |   |   |   |--- feature_4 <= -0.83
# |   |   |   |   |--- feature_0 <= 0.77
# |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- feature_0 >  0.77
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  -0.83
# |   |   |   |   |--- feature_5 <= -0.58
# |   |   |   |   |   |--- class: 3
# |   |   |   |   |--- feature_5 >  -0.58
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_3 >  -0.34
# |   |   |   |--- feature_4 <= -0.95
# |   |   |   |   |--- class: 3
# |   |   |   |--- feature_4 >  -0.95
# |   |   |   |   |--- feature_5 <= -0.42
# |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_5 >  -0.42
# |   |   |   |   |   |--- class: 3
# |   |--- feature_4 >  -0.22
# |   |   |--- feature_3 <= 0.68
# |   |   |   |--- feature_5 <= -0.49
# |   |   |   |   |--- class: 7
# |   |   |   |--- feature_5 >  -0.49
# |   |   |   |   |--- class: 5
# |   |   |--- feature_3 >  0.68
# |   |   |   |--- class: 8

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        70
#            2       1.00      1.00      1.00        79
#            3       0.99      0.99      0.99        77
#            5       1.00      1.00      1.00        86
#            6       1.00      1.00      1.00        79
#            7       0.99      0.99      0.99        68
#            8       1.00      1.00      1.00        89
#
#     accuracy                           1.00       548
#    macro avg       1.00      1.00      1.00       548
# weighted avg       1.00      1.00      1.00       548

# %% [markdown]
# #SVM

# %%
from tensorflow.keras import datasets 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
plt.style.use('seaborn')
import statsmodels.api as sm
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn import svm, datasets
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
poly = svm.SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)

# %%
poly_pred = poly.predict(X_test)
rbf_pred = rbf.predict(X_test)

# %%
poly_accuracy = accuracy_score(y_test, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))
graph2 = poly_accuracy*100
# Out:
# Accuracy (Polynomial Kernel):  93.61
# F1 (Polynomial Kernel):  93.60

# %%
rbf_accuracy = accuracy_score(y_test, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
# Out:
# Accuracy (RBF Kernel):  88.87
# F1 (RBF Kernel):  89.35

# %%
print(classification_report(poly_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.84      0.92        83
#            2       1.00      0.95      0.98        83
#            3       0.88      0.96      0.92        71
#            5       0.94      0.98      0.96        83
#            6       0.84      0.99      0.90        67
#            7       0.88      0.85      0.86        71
#            8       1.00      0.99      0.99        90
#
#     accuracy                           0.94       548
#    macro avg       0.93      0.94      0.93       548
# weighted avg       0.94      0.94      0.94       548

# %% [markdown]
# #ANN Model-1

# %%
from tensorflow.keras import datasets 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import cv2
plt.style.use('seaborn')
import statsmodels.api as sm
import tensorflow as tf

# %%
X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.layers import Flatten, Dense, InputLayer

# %%
hp_hidden_units = 128
hp_epoch = 20
hp_batch_size = 3
hp_lr = float(1/10)

# %%
l1 = Dense(40)
l2 = Dense(35, activation = tf.nn.relu)
l3 = Dense(25)
l4 = Dense(15,activation = tf.nn.relu)
l5 = Dense(14, activation = tf.nn.sigmoid)
m1 = keras.models.Sequential(
    [l1, l2, l3, l4, l5]
)

# %%
m1.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
           optimizer='adam',
           metrics=["accuracy"])

# %%
history1 =m1.fit(X_train, y_train, batch_size= hp_batch_size, epochs=hp_epoch)
# Out:
# Epoch 1/20
# 730/730 [==============================] - 3s 2ms/step - loss: 2.0439 - accuracy: 0.4486
# Epoch 2/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8829 - accuracy: 0.5436
# Epoch 3/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8631 - accuracy: 0.6364
# Epoch 4/20
# 730/730 [==============================] - 2s 3ms/step - loss: 1.8571 - accuracy: 0.6492
# Epoch 5/20
# 730/730 [==============================] - 2s 3ms/step - loss: 1.8562 - accuracy: 0.6313
# Epoch 6/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8547 - accuracy: 0.6414
# Epoch 7/20
# 730/730 [==============================] - 1s 2ms/step - loss: 1.8536 - accuracy: 0.6638
# Epoch 8/20
# 730/730 [==============================] - 1s 2ms/step - loss: 1.8484 - accuracy: 0.6651
# Epoch 9/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8466 - accuracy: 0.6884
# Epoch 10/20
# 730/730 [==============================] - 1s 2ms/step - loss: 1.8463 - accuracy: 0.6683
# Epoch 11/20
# 730/730 [==============================] - 2s 3ms/step - loss: 1.8462 - accuracy: 0.6894
# Epoch 12/20
# 730/730 [==============================] - 3s 4ms/step - loss: 1.8475 - accuracy: 0.7017
# Epoch 13/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8466 - accuracy: 0.7492
# Epoch 14/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8453 - accuracy: 0.7469
# Epoch 15/20
# 730/730 [==============================] - 2s 3ms/step - loss: 1.8440 - accuracy: 0.7387
# Epoch 16/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8456 - accuracy: 0.7620
# Epoch 17/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8425 - accuracy: 0.7771
# Epoch 18/20
# 730/730 [==============================] - 2s 3ms/step - loss: 1.8414 - accuracy: 0.7647
# Epoch 19/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8374 - accuracy: 0.7675
# Epoch 20/20
# 730/730 [==============================] - 2s 2ms/step - loss: 1.8442 - accuracy: 0.8255

# %%
p1 = m1.predict(X_test)
# Out:
# 18/18 [==============================] - 0s 2ms/step

# %%
import numpy as np
p1_reduced = [np.argmax(pr) for pr in p1]
p1_reduced[58]
# Out:
# 6

# %%
from sklearn.metrics import accuracy_score
print("Model 1: " + str(accuracy_score(p1_reduced, y_test)))
graph3= accuracy_score(p1_reduced, y_test)
# Out:
# Model 1: 0.8394160583941606

# %%
y_test[58]
# Out:
# 6.0

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
matrix = confusion_matrix(y_test,p1_reduced)
matrix
# Out:
# array([[21,  0, 49,  0,  0,  0,  0],
#        [ 0, 79,  0,  0,  0,  0,  0],
#        [ 0,  8, 66,  0,  2,  1,  0],
#        [ 0,  0,  0, 73,  1, 12,  0],
#        [ 0,  0,  0,  7, 68,  4,  0],
#        [ 0,  0,  1,  0,  3, 64,  0],
#        [ 0,  0,  0,  0,  0,  0, 89]])

# %%
print(classification_report(y_test,p1_reduced))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      0.30      0.46        70
#          2.0       0.91      1.00      0.95        79
#          3.0       0.57      0.86      0.68        77
#          5.0       0.91      0.85      0.88        86
#          6.0       0.92      0.86      0.89        79
#          7.0       0.79      0.94      0.86        68
#          8.0       1.00      1.00      1.00        89
#
#     accuracy                           0.84       548
#    macro avg       0.87      0.83      0.82       548
# weighted avg       0.87      0.84      0.83       548

# %%
df.to_csv('file_name.csv', encoding='utf-8')

# %%
sns.heatmap(df.corr(),annot=True)

# %%
from tensorflow.keras.utils import plot_model
print(m1.summary())
plot_model(m1, to_file='m1.png', show_shapes=False, show_layer_names=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 40)                600
#
#  dense_1 (Dense)             (None, 35)                1435
#
#  dense_2 (Dense)             (None, 25)                900
#
#  dense_3 (Dense)             (None, 15)                390
#
#  dense_4 (Dense)             (None, 14)                224
#
# =================================================================
# Total params: 3,549
# Trainable params: 3,549
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #ANN model-2

# %%
hp_hidden_units =20
hp_epoch = 10
hp_batch_size = 3
hp_lr = float(1/10)

# %%
l1 = Dense(20)
l2 = Dense(hp_hidden_units, activation = tf.nn.relu)
l3 = Dense(20, activation = tf.nn.relu)
l4 = Dense(10, activation = tf.nn.relu)
l5 = Dense(10, activation = tf.nn.softmax)
m2 = keras.models.Sequential(
    [l1, l2, l3, l4, l5]
)

# %%
import keras
from keras.callbacks import EarlyStopping


m2.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
           
           optimizer='rmsprop',
           metrics=["accuracy"])

# %%
history2 =m2.fit(X_train, y_train, batch_size= hp_batch_size, epochs=hp_epoch, validation_split=0.2,
                 shuffle=True, verbose=1
                 
                    )
# Out:
# Epoch 1/10
# 584/584 [==============================] - 3s 3ms/step - loss: 1.9474 - accuracy: 0.5740 - val_loss: 1.7717 - val_accuracy: 0.7123
# Epoch 2/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.7229 - accuracy: 0.7567 - val_loss: 1.7012 - val_accuracy: 0.7717
# Epoch 3/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.6671 - accuracy: 0.8070 - val_loss: 1.6569 - val_accuracy: 0.8174
# Epoch 4/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.6057 - accuracy: 0.8669 - val_loss: 1.5788 - val_accuracy: 0.8927
# Epoch 5/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5686 - accuracy: 0.9041 - val_loss: 1.5546 - val_accuracy: 0.9178
# Epoch 6/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5468 - accuracy: 0.9178 - val_loss: 1.5479 - val_accuracy: 0.9178
# Epoch 7/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5351 - accuracy: 0.9303 - val_loss: 1.5441 - val_accuracy: 0.9178
# Epoch 8/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5243 - accuracy: 0.9412 - val_loss: 1.5356 - val_accuracy: 0.9269
# Epoch 9/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5155 - accuracy: 0.9497 - val_loss: 1.5285 - val_accuracy: 0.9338
# Epoch 10/10
# 584/584 [==============================] - 1s 2ms/step - loss: 1.5100 - accuracy: 0.9560 - val_loss: 1.5242 - val_accuracy: 0.9406

# %%
history_dict = history2.history

# learning curve
# accuracy
acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

# loss
loss = history_dict['loss']
val_loss = history_dict['val_loss']

# range of X (no. of epochs)
epochs = range(1, len(acc) + 1)

# plot

# "r" is for "solid red line"
plt.plot(epochs, acc, 'r', label='Training accuracy')
# b is for "solid blue line"
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# loss
loss = history_dict['loss']
val_loss = history_dict['val_loss']

# range of X (no. of epochs)
epochs = range(1, len(acc) + 1)

# plot

# "r" is for "solid red line"
plt.plot(epochs, loss, 'r', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
sns.color_palette("Set2")
preds = m2.predict(X_test) 
print(preds[0]) 
print(np.sum(preds[0])) 

matrix = confusion_matrix(y_test, preds.argmax(axis=1))
matrix
print(classification_report(y_test, preds.argmax(axis=1)))
sns.heatmap(matrix)
# Out:
# 18/18 [==============================] - 0s 2ms/step
# [8.8517201e-22 9.9997419e-01 9.9557929e-10 2.5719080e-05 5.0543609e-23
#  1.8837779e-14 1.6535112e-13 9.7696885e-11 1.8199943e-20 9.8974680e-23]
# 0.99999994
#               precision    recall  f1-score   support
#
#          1.0       0.88      1.00      0.93        70
#          2.0       0.95      1.00      0.98        79
#          3.0       0.97      0.92      0.95        77
#          5.0       1.00      0.86      0.92        86
#          6.0       0.97      0.81      0.88        79
#          7.0       0.80      0.97      0.87        68
#          8.0       1.00      1.00      1.00        89
#
#     accuracy                           0.94       548
#    macro avg       0.94      0.94      0.93       548
# weighted avg       0.94      0.94      0.94       548

# %%
crop_name[np.argmax(preds[102])]
# Out:
# ['Jute', 'Watermelon', 'Muskmelon']

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test,preds.argmax(axis=1))
graph4=accuracy_score(y_test,preds.argmax(axis=1))

# %%
crop_name[y_test[102]]
m2.save_weights("ann.h5")

# %%
preds.argmax(axis=1)
# Out:
# array([1, 6, 2, 7, 8, 5, 1, 8, 2, 5, 2, 2, 8, 3, 3, 1, 5, 7, 5, 7, 2, 8,
#        1, 2, 2, 6, 1, 2, 8, 7, 8, 1, 3, 8, 3, 1, 5, 2, 5, 8, 3, 2, 6, 5,
#        7, 7, 5, 1, 5, 8, 8, 8, 6, 6, 7, 7, 8, 1, 6, 8, 8, 5, 8, 8, 2, 8,
#        2, 1, 7, 5, 5, 5, 2, 1, 5, 2, 2, 6, 8, 8, 1, 2, 1, 2, 2, 1, 3, 3,
#        3, 8, 6, 8, 1, 3, 7, 6, 7, 3, 7, 2, 7, 3, 3, 3, 8, 1, 7, 6, 1, 2,
#        1, 3, 5, 5, 1, 8, 6, 3, 6, 8, 6, 1, 7, 5, 6, 8, 5, 7, 3, 6, 3, 5,
#        2, 5, 1, 8, 8, 1, 3, 3, 2, 5, 2, 5, 8, 1, 2, 2, 6, 3, 7, 5, 3, 6,
#        8, 1, 1, 3, 8, 6, 6, 7, 8, 5, 8, 3, 1, 2, 5, 5, 1, 2, 2, 8, 3, 7,
#        7, 6, 1, 3, 3, 2, 5, 7, 5, 7, 5, 2, 7, 8, 7, 3, 2, 5, 2, 7, 2, 2,
#        8, 7, 1, 5, 5, 7, 8, 1, 8, 7, 3, 7, 7, 2, 8, 6, 6, 1, 8, 2, 1, 2,
#        5, 8, 1, 1, 7, 3, 6, 7, 3, 3, 3, 2, 8, 1, 5, 8, 8, 7, 6, 6, 1, 8,
#        2, 8, 8, 2, 5, 6, 2, 8, 7, 1, 7, 1, 3, 6, 2, 2, 5, 5, 8, 1, 1, 6,
#        8, 6, 5, 7, 8, 7, 1, 1, 2, 7, 6, 2, 7, 8, 1, 5, 2, 2, 5, 3, 5, 5,
#        1, 7, 1, 3, 7, 1, 3, 8, 2, 8, 1, 5, 8, 8, 6, 3, 2, 3, 3, 2, 2, 8,
#        3, 2, 1, 5, 2, 7, 8, 2, 7, 6, 1, 7, 6, 6, 5, 2, 6, 3, 2, 6, 2, 2,
#        1, 2, 8, 3, 2, 1, 1, 8, 3, 7, 5, 8, 3, 7, 8, 5, 1, 2, 7, 8, 1, 1,
#        6, 5, 8, 6, 5, 1, 3, 5, 3, 1, 1, 7, 7, 1, 7, 7, 2, 3, 2, 5, 3, 1,
#        8, 6, 1, 1, 3, 6, 8, 7, 8, 7, 6, 2, 8, 8, 7, 7, 7, 6, 5, 2, 5, 3,
#        8, 3, 3, 1, 7, 2, 3, 5, 7, 2, 5, 7, 7, 7, 5, 8, 3, 7, 3, 5, 3, 7,
#        5, 3, 8, 1, 7, 1, 8, 7, 8, 8, 6, 7, 2, 6, 8, 7, 2, 2, 3, 6, 1, 3,
#        7, 2, 2, 6, 7, 7, 3, 5, 7, 5, 7, 1, 6, 7, 3, 6, 6, 1, 1, 5, 6, 3,
#        8, 2, 3, 2, 3, 6, 6, 1, 6, 8, 5, 3, 5, 7, 2, 3, 5, 6, 3, 3, 8, 8,
#        7, 2, 1, 2, 6, 6, 6, 5, 7, 2, 3, 6, 2, 8, 7, 6, 6, 8, 8, 1, 5, 1,
#        2, 5, 5, 1, 1, 7, 2, 2, 1, 6, 8, 3, 1, 6, 5, 6, 3, 7, 5, 3, 6, 2,
#        6, 1, 8, 7, 8, 5, 8, 8, 7, 1, 7, 8, 5, 7, 6, 8, 5, 3, 1, 5])

# %%
from tensorflow.keras.utils import plot_model
print(m2.summary())
plot_model(m2, to_file='m2.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 20)                300
#
#  dense_6 (Dense)             (None, 20)                420
#
#  dense_7 (Dense)             (None, 20)                420
#
#  dense_8 (Dense)             (None, 10)                210
#
#  dense_9 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 1,460
# Trainable params: 1,460
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #random forest

# %%
labels = np.array(y)

# %%
features = np.array(X)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (2052, 14)
# Training Labels Shape: (2052,)
# Testing Features Shape: (685, 14)
# Testing Labels Shape: (685,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
rf.fit(train_features, train_labels);

# %%
predictions = rf.predict(test_features)
errors = abs(predictions - test_labels)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.01 degrees.

# %%
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
graph5= round(accuracy, 2)
# Out:
# Accuracy: 99.78 %.

# %%
# !pip install pydot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot) (3.0.9)

# %%
from sklearn.tree import export_graphviz
import pydot
# Pull out one tree from the forest
tree = rf.estimators_[5]
# Import tools needed for visualization
from sklearn.tree import export_graphviz
import pydot

# %% [markdown]
# #xgboost

# %%
# !pip3 install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.7.3)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
modelXG = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')

# %%
modelXG.fit(X_train, y_train)
# Out:
# XGBClassifier(eval_metric='mlogloss', objective='multi:softprob',
#               use_label_encoder=False)

# %%
y_predxg = modelXG.predict(X_test)

# %%
graph6 = accuracy_score(y_test, y_predxg)
accuracy
# Out:
# 99.78491484184914

# %%
print(classification_report(y_test,y_predxg))
# Out:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00        70
#          2.0       1.00      1.00      1.00        79
#          3.0       0.99      1.00      0.99        77
#          5.0       1.00      1.00      1.00        86
#          6.0       1.00      1.00      1.00        79
#          7.0       1.00      0.99      0.99        68
#          8.0       1.00      1.00      1.00        89
#
#     accuracy                           1.00       548
#    macro avg       1.00      1.00      1.00       548
# weighted avg       1.00      1.00      1.00       548

# %%
graph2=graph2/100
graph5=graph5/100
acc_list=[graph,graph2,graph3,graph4,graph5,graph6]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc_list,y = index,palette='dark')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-5e95d6e5596c> in <module>
#       4 plt.xlabel('Accuracy')
#       5 plt.ylabel('Algorithm')
# ----> 6 sns.barplot(x = acc_list,y = index,palette='dark')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
#    3187     if ax is None:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     155             # Figure out the plotting orientation
#     156             orient = infer_orient(
# --> 157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#     159
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1310
#    1311     x_type = None if x is None else variable_type(x)
# -> 1312     y_type = None if y is None else variable_type(y)
#    1313
#    1314     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py in variable_type(vector, boolean_type)
#    1227
#    1228     # Special-case all-na data, which is always "numeric"
# -> 1229     if pd.isna(vector).all():
#    1230         return "numeric"
#    1231
#
# AttributeError: 'bool' object has no attribute 'all'

# %%
graph

# %%
graph2=graph2/100

# %%
graph5=graph5/100

# %%
acc_list

# %%
index= ['Decision Tree',"SVM","ANN M1","ANN M2","Random Forest","Xgboost"]

# %%
precison_list= [0.99,0.94,0.71,0.95,0.98,0.99]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Precision')
plt.xlabel('Precision')
plt.ylabel('Algorithm')
sns.barplot(x = precison_list,y = index,palette='dark')

# %%
acc_list2 = [graph3*100,graph4*100]

# %%
index= ["ANN Model 1 using sigmoid and adam","ANN Model 2 using softmax and rmsprop"]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc_list2,y = index,palette='dark')

# %% [markdown]
# #prediction function

# %%
my = df[['pH', 'EC', 'OC', 'N', 'P', 'K', 'S', 'Ca', 'Mg', 'Zn', 'Cu',
       'Fe', 'Mn','Tex']]

# %%
ph = 6.24
ec = 0.62
oc = 14.34
n = 511.52
p = 21.3
k = 102.8
s = 620
ca = 72
mg = 0.39
zn = 1.16
cu = 11.99
fe = 15.13
mn = 6.2
tex = 16

lst = [[ph, ec, oc, n, p, k, s, ca, mg, zn, cu, fe, mn, tex]]
arr = np.array(lst)
mean = np.array(my.mean())
std = np.array(my.std())
arr = (arr-mean)/std

# %%
pred = m2.predict(arr)
pred.argmax(axis=1)[0]
print(crop_name[pred.argmax(axis=1)[0]])
# Out:
# 1/1 [==============================] - 0s 18ms/step
# ['Cotton', 'Jute', 'Watermelon', 'Muskmelon', 'Banana', 'Orange']

# %% [markdown]
# #District Prediction

# %%
X1 = df[['pH', 'EC', 'OC', 'N', 'P', 'K', 'S', 'Ca', 'Mg', 'Zn', 'Cu',
       'Fe', 'Mn','Tex']]
Y1 = df[['District']]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Y1.District= le.fit_transform(df.District.values)
X1.Tex= le.fit_transform(df.Tex.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
X1
# Out:
#             pH        EC         OC           N          P           K  \
# 0     7.050000  0.160000   5.560000  175.620000  38.260000  324.800000
# 1     6.880000  0.089000   4.240000  125.440000  26.300000  103.000000
# 2     5.600000  0.081000   2.780000  150.530000  25.700000   53.800000
# 3     7.300000  0.164000  10.540000  188.160000  24.700000  190.400000
# 4     7.220000  0.167000  11.410000  163.070000  40.000000  210.600000
# ...        ...       ...        ...         ...        ...         ...
# 2732  6.531352  0.659126  17.283696  507.723181  28.210970   99.076266
# 2733  6.570766  0.672140  17.198919  507.854437  28.107230   99.429503
# 2734  6.989972  0.810557  16.297230  509.250472  27.003848  103.186541
# 2735  6.737222  0.727102  16.840881  508.408768  27.669104  100.921331
# 2736  6.215602  0.554868  17.962857  506.671674  29.042048   96.246431
#
#                S    Ca          Mg         Zn         Cu         Fe  \
# 0       5.210000  1884  288.000000   1.820000   0.200000   2.830000
# 1      10.420000  1484  336.000000   1.620000   0.450000   6.270000
# 2       7.810000  1644  504.000000   2.840000   0.440000  21.080000
# 3      10.420000  1364  840.000000   7.740000   0.630000  16.420000
# 4      10.420000  2004  168.000000  11.890000   0.610000   7.380000
# ...          ...   ...         ...        ...        ...        ...
# 2732  464.099932    57    1.407825   0.908700  26.714008  20.307160
# 2733  462.612618    60    1.410428   0.898288  25.791129  19.426670
# 2734  446.793514    93    1.438111   0.787555  15.975375  10.061760
# 2735  456.331240    73    1.421420   0.854319  21.893534  15.708094
# 2736  476.015029    32    1.386974   0.992105  34.107325  27.360897
#
#              Mn  Tex
# 0      2.800000    2
# 1      5.600000    2
# 2     24.110000    5
# 3     11.400000    2
# 4      2.910000    2
# ...         ...  ...
# 2732   8.306451   14
# 2733   8.329504   14
# 2734   8.574701   16
# 2735   8.426866   15
# 2736   8.121767   12
#
# [2737 rows x 14 columns]

# %%
Y1['District'].unique()
# Out:
# array([0, 2, 1])

# %%
X1 = (X1 - X1.mean())/X1.std()
X1
# Out:
#             pH        EC        OC         N         P         K         S  \
# 0     1.048506 -1.037491 -1.677114 -1.226424  0.557077  1.249438 -1.023138
# 1     0.650186 -1.200279 -1.911359 -1.594217 -0.124451 -0.593699 -1.014431
# 2    -2.348933 -1.218622 -2.170448 -1.410321 -0.158642 -1.002546 -1.018793
# 3     1.634272 -1.028320 -0.793373 -1.134513 -0.215626  0.132587 -1.014431
# 4     1.446827 -1.021441 -0.638984 -1.318409  0.656229  0.300447 -1.014431
# ...        ...       ...       ...       ...       ...       ...       ...
# 2732 -0.166718  0.106901  0.403351  1.207717 -0.015557 -0.626305 -0.256227
# 2733 -0.074369  0.136739  0.388306  1.208679 -0.021468 -0.623369 -0.258713
# 2734  0.907857  0.454101  0.228294  1.218911 -0.084343 -0.592149 -0.285150
# 2735  0.315649  0.262756  0.324770  1.212742 -0.046434 -0.610972 -0.269211
# 2736 -0.906540 -0.132139  0.523873  1.200010  0.031801 -0.649820 -0.236315
#
#             Ca        Mg        Zn        Cu        Fe        Mn       Tex
# 0     1.526581  0.178608 -0.192447 -0.946238 -1.027180 -0.943989 -2.426073
# 1     1.071609  0.288384 -0.255630 -0.931182 -0.754868 -0.599579 -2.426073
# 2     1.253598  0.672599  0.129790 -0.931784  0.417502  1.677216 -1.721297
# 3     0.935117  1.441030  1.677788 -0.920342  0.048613  0.113841 -2.426073
# 4     1.663073 -0.095832  2.988847 -0.921546 -0.666999 -0.930458 -2.426073
# ...        ...       ...       ...       ...       ...       ...       ...
# 2732 -0.551505 -0.476827 -0.480343  0.650537  0.356323 -0.266676  0.393030
# 2733 -0.548092 -0.476821 -0.483632  0.594957  0.286623 -0.263840  0.393030
# 2734 -0.510557 -0.476758 -0.518615  0.003815 -0.454709 -0.233680  0.862880
# 2735 -0.533306 -0.476796 -0.497523  0.360229 -0.007742 -0.251865  0.627955
# 2736 -0.579940 -0.476875 -0.453993  1.095790  0.914702 -0.289393 -0.076821
#
# [2737 rows x 14 columns]

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, Y1, test_size=0.2)
print(X1_train.shape, X1_test.shape, y1_train.shape, y1_test.shape)
# Out:
# (2189, 14) (548, 14) (2189, 1) (548, 1)

# %%
X1_train = np.asarray(X1_train).astype(np.float32)

X1_test = np.asarray(X1_test).astype(np.float32)

# %%
hp_hidden_units = 45
hp_epoch = 10
hp_batch_size = 3
hp_lr = float(1/10)

# %%
l1 = Dense(40)
l2 = Dense(35, activation = tf.nn.relu)
l3 = Dense(20)
l4 = Dense(10, activation = tf.nn.softmax)
d = keras.models.Sequential(
    [l1, l2, l3, l4]
)

# %%
from tensorflow.keras.layers import Flatten, Dense, InputLayer

# %%
d.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
           optimizer='adam',
           metrics=["accuracy"])

# %%
history3 =d.fit(X1_train, y1_train, batch_size= 10, epochs=3)
# Out:
# Epoch 1/3
# 219/219 [==============================] - 1s 2ms/step - loss: 1.6340 - accuracy: 0.8652
# Epoch 2/3
# 219/219 [==============================] - 0s 2ms/step - loss: 1.4780 - accuracy: 0.9849
# Epoch 3/3
# 219/219 [==============================] - 1s 2ms/step - loss: 1.4768 - accuracy: 0.9849

# %%
districts = { 0 : ["Almora"], 1 : ["Tehri"], 2 : ["Chamoli"]}

# %%
predsd = d.predict(X1_test)
# Out:
# 18/18 [==============================] - 0s 2ms/step

# %%
districts[np.argmax(predsd[50])]
# Out:
# ['Tehri']

# %%
d.save('district.h5')

# %% [markdown]
# #Fertility Scale

# %%
n = 0
p = 0
k = 0
s = 0
oc = 0
ca = 0
score = 0

label = []

# %%
for i in range(df.shape[0]):
    if(df.loc[i]['N']<=280):
        n=1
    elif(df.loc[i]['N']>280 and df.loc[i]['N']<=560):
        n=2
    elif(df.loc[i]['N']>560):
        n=3
        
        
    
    if(df.loc[i]['P']<=10):
        p=1
    elif(df.loc[i]['P']>10 and df.loc[i]['P']<=24.6):
        p=2
    elif(df.loc[i]['P']>24.6):
        p=3
        
        
        
    if(df.loc[i]['K']<=117.6):
        k=1
    elif(df.loc[i]['K']>117.6 and df.loc[i]['K']<=280):
        k=2
    elif(df.loc[i]['K']>280):
        k=3
        
    if(df.loc[i]['S']<=10):
        s=1
    elif(df.loc[i]['S']>10 and df.loc[i]['S']<=20):
        s=2
    elif(df.loc[i]['S']>20):
        s=3
        
    if(df.loc[i]['OC']<=0.5):
        oc=3
    elif(df.loc[i]['OC']>0.5 and df.loc[i]['OC']<=0.75):
        oc=6
    elif(df.loc[i]['OC']>0.75):
        oc=9
        
    if(df.loc[i]['Ca']<=2500):
        ca=1
    elif(df.loc[i]['Ca']>2500 and df.loc[i]['Ca']<=4000):
        ca=2
    elif(df.loc[i]['Ca']>4000):
        ca=3   
        
    score = ((n+p+k+s+oc+ca)*10)/28.35
    
    
    label.append((score))

# %%
sns.histplot(label)
